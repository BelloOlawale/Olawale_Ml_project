# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\OlawaleBello\Documents\bank_data.csv")
df.head()
# Out:
#    Unnamed: 0  age          job  marital  education default  balance housing  \
# 0           0   30   unemployed  married    primary      no     1787      no
# 1           1   33     services  married  secondary      no     4789     yes
# 2           2   35   management   single   tertiary      no     1350     yes
# 3           3   30   management  married   tertiary      no     1476     yes
# 4           4   59  blue-collar  married  secondary      no        0     yes
#
#   loan   contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  cellular   19   oct        79         1     -1         0  unknown  no
# 1  yes  cellular   11   may       220         1    339         4  failure  no
# 2   no  cellular   16   apr       185         1    330         1  failure  no
# 3  yes   unknown    3   jun       199         4     -1         0  unknown  no
# 4   no   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4521 non-null   int64
#  1   age         4521 non-null   int64
#  2   job         4521 non-null   object
#  3   marital     4521 non-null   object
#  4   education   4521 non-null   object
#  5   default     4521 non-null   object
#  6   balance     4521 non-null   int64
#  7   housing     4521 non-null   object
#  8   loan        4521 non-null   object
#  9   contact     4521 non-null   object
#  10  day         4521 non-null   int64
#  11  month       4521 non-null   object
#  12  duration    4521 non-null   int64
#  13  campaign    4521 non-null   int64
#  14  pdays       4521 non-null   int64
#  15  previous    4521 non-null   int64
#  16  poutcome    4521 non-null   object
#  17  y           4521 non-null   object
# dtypes: int64(8), object(10)
# memory usage: 635.9+ KB

# %%
df.shape
# Out:
# (4521, 18)

# %%
df.describe()
# Out:
#         Unnamed: 0          age       balance          day     duration  \
# count  4521.000000  4521.000000   4521.000000  4521.000000  4521.000000
# mean   2260.000000    41.170095   1422.657819    15.915284   263.961292
# std    1305.244613    10.576211   3009.638142     8.247667   259.856633
# min       0.000000    19.000000  -3313.000000     1.000000     4.000000
# 25%    1130.000000    33.000000     69.000000     9.000000   104.000000
# 50%    2260.000000    39.000000    444.000000    16.000000   185.000000
# 75%    3390.000000    49.000000   1480.000000    21.000000   329.000000
# max    4520.000000    87.000000  71188.000000    31.000000  3025.000000
#
#           campaign        pdays     previous
# count  4521.000000  4521.000000  4521.000000
# mean      2.793630    39.766645     0.542579
# std       3.109807   100.121124     1.693562
# min       1.000000    -1.000000     0.000000
# 25%       1.000000    -1.000000     0.000000
# 50%       2.000000    -1.000000     0.000000
# ...

# %%
df.describe(include=['object'])
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         4521     4521       4521    4521    4521  4521      4521  4521
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq           969     2797       2306    4445    2559  3830      2896  1398
#
#        poutcome     y
# count      4521  4521
# unique        4     2
# top     unknown    no
# freq       3705  4000

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0          age         job  marital  education default  \
# count   4521.000000  4521.000000        4521     4521       4521    4521
# unique          NaN          NaN          12        3          4       2
# top             NaN          NaN  management  married  secondary      no
# freq            NaN          NaN         969     2797       2306    4445
# mean    2260.000000    41.170095         NaN      NaN        NaN     NaN
# std     1305.244613    10.576211         NaN      NaN        NaN     NaN
# min        0.000000    19.000000         NaN      NaN        NaN     NaN
# 25%     1130.000000    33.000000         NaN      NaN        NaN     NaN
# 50%     2260.000000    39.000000         NaN      NaN        NaN     NaN
# 75%     3390.000000    49.000000         NaN      NaN        NaN     NaN
# max     4520.000000    87.000000         NaN      NaN        NaN     NaN
#
#              balance housing  loan   contact          day month     duration  \
# ...

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# job          object
# marital      object
# education    object
# default      object
# housing      object
# loan         object
# contact      object
# month        object
# poutcome     object
# y            object
# dtype: object

# %%
all_duplicates = df.duplicated(keep=False).sum()
print(all_duplicates)
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# y             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# %%
df_train = train_set.copy() # creating a copy of the train set for further eda

# %%
# plotting histograms for all numerical features
import matplotlib.pyplot as plt
df_train.hist(bins=50, figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
# Working with the train set and only use the test set for validation.
print(f"The shpae of the train set is {train_set.shape} and the shape of the set is {test_set.shape}")
# Out:
# The shpae of the train set is (3616, 18) and the shape of the set is (905, 18)

# %%
# looking for correlations in the dataset
corr_matrix = df_train.corr(numeric_only=True)

# how each features correlate with the target
corr_matrix["previous"].sort_values(ascending=False)
# Out:
# previous      1.000000
# pdays         0.570318
# balance       0.037435
# duration      0.031264
# Unnamed: 0    0.004402
# age          -0.009201
# day          -0.053855
# campaign     -0.063609
# Name: previous, dtype: float64

# %%
# Heapmap
# Generate a mask for the upper triangle
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = 1

# Make the figsize 10 x 8
plt.figure(figsize=(10,8))

# Plot heatmap of correlations
sns.heatmap(corr_matrix * 100,
            cmap='RdBu_r',
            annot=True,
            fmt='.0f',
            mask=mask)
plt.tight_layout()
plt.show()

# %%
# Unique values in each categorical column
for col in df.select_dtypes(include='object').columns:
    print(f"{col}: {df[col].nunique()} unique values")
    print(df[col].value_counts().head(), "\n")
# Out:
# job: 12 unique values
# job
# management     969
# blue-collar    946
# technician     768
# admin.         478
# services       417
# Name: count, dtype: int64
#
# marital: 3 unique values
# marital
# married     2797
# single      1196
# divorced     528
# Name: count, dtype: int64
#
# education: 4 unique values
# education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64
#
# default: 2 unique values
# default
# no     4445
# yes      76
# Name: count, dtype: int64
#
# housing: 2 unique values
# housing
# yes    2559
# no     1962
# Name: count, dtype: int64
#
# loan: 2 unique values
# loan
# no     3830
# yes     691
# Name: count, dtype: int64
#
# contact: 3 unique values
# contact
# cellular     2896
# unknown      1324
# telephone     301
# Name: count, dtype: int64
#
# month: 12 unique values
# month
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# #EDA FOR NUMERIC FEATURES

# %%
df.campaign.unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44])

# %%
import matplotlib.pyplot as plt
df_train.hist(bins=50, figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
print(f"The shpae of the train set is {train_set.shape} and the shape of the test set is {test_set.shape}")
# Out:
# The shpae of the train set is (3616, 18) and the shape of the test set is (905, 18)

# %%
corr_matrix = df_train.corr(numeric_only=True)

# how each features correlate with the target
corr_matrix["balance"].sort_values(ascending=False)
# Out:
# balance       1.000000
# age           0.095975
# previous      0.037435
# pdays         0.025639
# Unnamed: 0    0.002943
# day          -0.000927
# campaign     -0.003223
# duration     -0.013910
# Name: balance, dtype: float64

# %%
import seaborn as sns

mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = 1

plt.figure(figsize=(10,8))

# Plot heatmap of correlations
sns.heatmap(corr_matrix * 100,
            cmap='RdBu_r',
            annot=True,
            fmt='.0f',
            mask=mask)
plt.tight_layout()
plt.show()

# %%
from pandas.plotting import scatter_matrix
attributes = [
    'duration', 'age', 'day', 'pdays',
    'campaign', 'previous',
]

scatter_matrix(df_train[attributes], figsize=(20, 15))
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df_train['age'], bins=30, kde=True)
plt.title('Distribution of subscription')
plt.xlabel('age')
plt.ylabel('subscribed')
plt.show()

# %%
df['was_previously_contacted'] = df['pdays'].apply(lambda x: 0 if x == -1 else 1)

#  Examine the 'poutcome' column and apply one-hot encoding
df = pd.get_dummies(df, columns=['poutcome'], drop_first=True)

#  Look at the 'contact' column and apply one-hot encoding
df = pd.get_dummies(df, columns=['contact'], drop_first=True)

#  Review the 'month' and 'day' columns - One-hot encode month as an initial approach
df = pd.get_dummies(df, columns=['month'], drop_first=True)
# Day can be kept as is or potentially explored later for daily patterns

# Analyze the 'education' column - Apply one-hot encoding as there isn't a strict ordinal relationship universally
df = pd.get_dummies(df, columns=['education'], drop_first=True)



# Drop the original 'pdays' column as it's replaced by 'was_previously_contacted'
df = df.drop('pdays', axis=1)

# Drop the 'Unnamed: 0' column as it seems to be just an index
df = df.drop('Unnamed: 0', axis=1)

display(df.head())
# Out:
#    age          job  marital default  balance housing loan  day  duration  \
# 0   30   unemployed  married      no     1787      no   no   19        79
# 1   33     services  married      no     4789     yes  yes   11       220
# 2   35   management   single      no     1350     yes   no   16       185
# 3   30   management  married      no     1476     yes  yes    3       199
# 4   59  blue-collar  married      no        0     yes   no    5       226
#
#    campaign  ...  month_jul month_jun  month_mar  month_may  month_nov  \
# 0         1  ...      False     False      False      False      False
# 1         1  ...      False     False      False       True      False
# 2         1  ...      False     False      False      False      False
# 3         4  ...      False      True      False      False      False
# 4         1  ...      False     False      False       True      False
#
#    month_oct  month_sep  education_secondary  education_tertiary  \
# ...
